# %% [markdown]
# # 0. Importar librerías

# %%
import yfinance as yf
import pyfolio as pf
from datetime import datetime as dt, timedelta as td
# Out:
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %% [markdown]
# # 1. Crear fechas y bajar datos

# %%
start_dt = dt(1993, 1, 1)
end_dt = dt.today()
ticker = "SPY"

df = yf.download(ticker, start=start_dt, end=end_dt)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # 2. Calcular retornos

# %%
rets = df["Adj Close"].pct_change().dropna()

# %% [markdown]
# # 3. Tear sheet

# %%
pf.create_returns_tear_sheet(rets)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1993-02-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-02-09</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>348</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>10.441%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>1683.563%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.719%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.62</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.19</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-55.189%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.13</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.06</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>12.09</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.312%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>55.19</td>
#       <td>2007-10-09</td>
#       <td>2009-03-09</td>
#       <td>2012-08-16</td>
#       <td>1268</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>47.52</td>
#       <td>2000-03-24</td>
#       <td>2002-10-09</td>
#       <td>2006-10-26</td>
#       <td>1720</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>33.72</td>
#       <td>2020-02-19</td>
#       <td>2020-03-23</td>
#       <td>2020-08-10</td>
#       <td>124</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>19.35</td>
#       <td>2018-09-20</td>
#       <td>2018-12-24</td>
#       <td>2019-04-12</td>
#       <td>147</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>19.03</td>
#       <td>1998-07-20</td>
#       <td>1998-08-31</td>
#       <td>1998-11-23</td>
#       <td>91</td>
#     </tr>
#   </tbody>
# </table>
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:418: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:418: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:418: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:418: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:418: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:418: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:418: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
# /Users/carlos/opt/anaconda3/envs/dsp/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:418: MatplotlibDeprecationWarning:
# The is_last_row function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_last_row() instead.
#   if ax.is_last_row():
